# %% [markdown]
# ___
#
# Mr. Yogesh P Murumkar (Mob. 9657080905)
# ___
# # Seaborn Exercises
#
# Time to practice your new seaborn skills! Try to recreate the plots below (don't worry about color schemes, just the plot itself.

# %% [markdown]
# ## The Data
#
# We will be working with a famous titanic data set for these exercises. Later on in the Machine Learning section of the course, we will revisit this data, and use it to predict survival rates of passengers. For now, we'll just focus on the visualization of the data with seaborn:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
# titanic = sns.load_dataset('titanic')

titanic = pd.read_csv("titanic.csv")

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# # Exercises
#
# ** Recreate the plots below using the titanic dataframe. There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution. Keep careful attention to the x and y labels for hints.**
#
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# fig , axes = plt.subplots(1,2,figsize = (12,5))

# sns.scatterplot(data = titanic, x="Fare" , y="Age", ax=axes[0])
# axes[0].set_xlabel("Fare")
# axes[0].set_ylabel("Age")

sns.jointplot(x="Fare" , y = "Age", data=titanic,kind="scatter")

# sns.histplot(data = titanic, x="Fare" , bins=20 , ax = axes[1])
# axes[1].set_xlabel("Fare")
# axes[1].set_ylabel("Age")

plt.show()

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

sns.histplot(data = titanic, x="Fare" , bins=20 , color = "Red" )
plt.xlabel("Fare")
plt.ylabel("Age")
plt.show()

# fig , axes = plt.subplots(1,2,figsize = (12,5))
# sns.histplot(data = titanic, x="Fare" , bins=20 , ax = axes[1])
# axes[1].set_xlabel("Fare")
# axes[1].set_ylabel("Age")

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

plt.figure(figsize=(8,5))
sns.boxplot(x="Pclass" , y="Age" , data = titanic, palette='rainbow')
plt.title("Plot")
plt.show()
# Out:
# C:\Users\Snehal.Naik\AppData\Local\Temp\ipykernel_19540\2835208470.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Pclass" , y="Age" , data = titanic, palette='rainbow')

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

plt.figure(figsize = (8,6))

custom_palette = {
    '1' : 'green',
    '2' : 'orange',
    '3' : 'purple'
}

sns.swarmplot(x = "Pclass" , y = "Age", data = titanic , palette=custom_palette)
plt.xlabel("Pclass")
plt.ylabel("Age")



plt.show()
# Out:
# C:\Users\Snehal.Naik\AppData\Local\Temp\ipykernel_19540\2954875904.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x = "Pclass" , y = "Age", data = titanic , palette=custom_palette)

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

custom_palette = {
    'male' : 'blue',
    'female' : 'green'
}


plt.figure(figsize=(8,5))
sns.countplot( data=titanic , x='Sex', palette=custom_palette)
plt.show()
# Out:
# C:\Users\Snehal.Naik\AppData\Local\Temp\ipykernel_19540\3203925053.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot( data=titanic , x='Sex', palette=custom_palette)

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

corr_matrix = titanic.corr(numeric_only=True)
plt.figure(figsize = (10,8))
sns.heatmap(corr_matrix , annot = False, cmap='coolwarm' , fmt = '.2f' , linewidths=.5)
plt.show()

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
sns.displot(data = titanic , x="Age" , col = "Sex" , bins = 20)

plt.show()

# %% [markdown]
# # Great Job!
#
# ### That is it for now! We'll see a lot more of seaborn practice problems in the machine learning section!
